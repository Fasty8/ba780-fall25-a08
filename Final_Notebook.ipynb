# %% [markdown]
# # Title

# %% [markdown]
# ## Project Proposal

# %% [markdown]
# ## Team Assignment Phase

# %% [markdown]
# ## Executive Summary
# Anna, Yue

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References

# %% [markdown]
# ## Generative AI
