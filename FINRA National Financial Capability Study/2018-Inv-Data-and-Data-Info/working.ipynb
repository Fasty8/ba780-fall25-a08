# %%
import pandas as pd

# Replace the path below with your actual file path if needed
file_path = "NFCS 2018 Investor Data 191107.sav"

# Read the .sav file into a pandas DataFrame
df = pd.read_spss(file_path)

# Display the first few rows
df.head()
# Out:
#          NFCSID                                                 A1   A2   A3  \
# 0  2.018010e+09  I share the decision-making responsibility whe...  Yes  Yes
# 1  2.018010e+09  I am the primary decision-maker when it comes ...  Yes  Yes
# 2  2.018010e+09  I share the decision-making responsibility whe...  Yes  Yes
# 3  2.018010e+09  I am the primary decision-maker when it comes ...  Yes  Yes
# 4  2.018010e+09  I am the primary decision-maker when it comes ...  Yes  Yes
#
#          B2_1        B2_2 B2_3 B2_4        B2_5 B2_7  ...         G12  \
# 0  Don't know  Don't know  Yes  Yes  Don't know   No  ...          $0
# 1         Yes         Yes  Yes  Yes         Yes   No  ...        $250
# 2         Yes         Yes   No   No          No   No  ...  Don't know
# 3          No          No  Yes   No         Yes   No  ...        $500
# 4         Yes         Yes  Yes  Yes          No  Yes  ...          $0
#
#                                                  G13   H2   H3      WGT1  \
# ...
